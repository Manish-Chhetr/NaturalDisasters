# %%
import time
import datetime as dt
import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import linear_model
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

# %%
main_df = pd.read_csv('eq_database_place.csv')
dummy_eq = main_df.copy()

# %%
dummy_df = dummy_eq[dummy_eq['Place'].str.contains('JP')]
# dummy_df = dummy_df.reindex(np.random.permutation(dummy_df.index))
dummy_df.head()
# Out:
#            Date      Time  Latitude  Longitude        Type  Depth  \
# 55   02/16/1965  12:24:10    38.908    142.095  Earthquake   53.5
# 89   03/16/1965  16:46:17    40.697    143.032  Earthquake   32.1
# 101  03/29/1965  10:47:38    40.687    142.915  Earthquake   30.0
# 111  04/06/1965  05:31:59    36.083    139.968  Earthquake   50.0
# 122  04/15/1965  05:09:50    25.080    122.897  Earthquake  165.0
#
#      Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 55           NaN                     NaN        5.7             MW
# 89           NaN                     NaN        6.4             MW
# 101          NaN                     NaN        6.4             MW
# 111          NaN                     NaN        5.7             MW
# 122          NaN                     NaN        5.6             MW
#
#          ...       Azimuthal Gap  Horizontal Distance  Horizontal Error  \
# 55       ...                 NaN                  NaN               NaN
# 89       ...                 NaN                  NaN               NaN
# 101      ...                 NaN                  NaN               NaN
# 111      ...                 NaN                  NaN               NaN
# 122      ...                 NaN                  NaN               NaN
#
#      Root Mean Square            ID  Source Location Source Magnitude Source  \
# 55                NaN  ISCGEM860246  ISCGEM          ISCGEM           ISCGEM
# 89                NaN  ISCGEM858655  ISCGEM          ISCGEM           ISCGEM
# 101               NaN  ISCGEM858966  ISCGEM          ISCGEM           ISCGEM
# 111               NaN  ISCGEM857506  ISCGEM          ISCGEM           ISCGEM
# 122               NaN  ISCGEM857769  ISCGEM          ISCGEM           ISCGEM
#
#         Status         Place
# 55   Automatic   Ofunato, JP
# 89   Automatic      Kuji, JP
# 101  Automatic      Kuji, JP
# 111  Automatic    Ishige, JP
# 122  Automatic  Yonakuni, JP
#
# [5 rows x 22 columns]

# %% [markdown]
# ## NaN removing function

# %%
def nan_helper(y):
    """
    Helper to handle indices and logical indices of NaNs.
    Input:
        - y, 1d numpy array with possible NaNs
    Output:
        - nans, logical indices of NaNs
        - index, a function, with signature indices= index(logical_indices),
          to convert logical indices of NaNs to 'equivalent' indices
    Example:
        >>> # linear interpolation of NaNs
        >>> nans, x= nan_helper(y)
        >>> y[nans]= np.interp(x(nans), x(~nans), y[~nans])
    """
    
    return np.isnan(y), lambda z: z.nonzero()[0]

# %% [markdown]
# ## String label encoding

# %%
def label_integer_encoder(my_df, series_name):
    """
    This function is encoding values of a series
    Parameter
    ---------
    * `my_df`: Pandas dataframe
    * `series_name`: Pandas series name to encode
    Returns : a encoded array
    """
    arr_name = np.array(list(my_df[str(series_name)]))
    label_arr_encoder = LabelEncoder()
    integer_arr_encoded = label_arr_encoder.fit_transform(arr_name)
    
    return integer_arr_encoded

# %% [markdown]
# ## Interpolation function

# %%
def get_interpolation(my_df, nan_series):
    arr_series = np.array(my_df[str(nan_series)])
    nans, x = nan_helper(arr_series)
    arr_series[nans] = np.interp(x(nans), x(~nans), arr_series[~nans])
    return arr_series.round(2)

# %% [markdown]
# ## Removing NaN values from the series

# %%
dummy_df['Depth Error'] = get_interpolation(dummy_df, 'Depth Error')
dummy_df['Depth Seismic Stations'] = get_interpolation(dummy_df, 'Depth Seismic Stations')
dummy_df['Magnitude Error'] = get_interpolation(dummy_df, 'Magnitude Error')
dummy_df['Magnitude Seismic Stations'] = get_interpolation(dummy_df, 'Magnitude Seismic Stations')
dummy_df['Azimuthal Gap'] = get_interpolation(dummy_df, 'Azimuthal Gap')
dummy_df['Horizontal Distance'] = get_interpolation(dummy_df, 'Horizontal Distance')
dummy_df['Horizontal Error'] = get_interpolation(dummy_df, 'Horizontal Error')
dummy_df['Root Mean Square'] = get_interpolation(dummy_df, 'Root Mean Square')

# %% [markdown]
# ## Actual encoding of strings

# %%
dummy_df['Type'] = label_integer_encoder(dummy_df, 'Type')
dummy_df['Magnitude Type'] = label_integer_encoder(dummy_df, 'Magnitude Type')
dummy_df['Place'] = label_integer_encoder(dummy_df, 'Place')
dummy_df['Status'] = label_integer_encoder(dummy_df, 'Status')

# %% [markdown]
# ## Dropping unwanted

# %%
dummy_df = dummy_df.drop(['ID', 'Source', 'Location Source', 'Magnitude Source'], axis=1)

# %% [markdown]
# ## Time object numerical values

# %%
timestamp = []
for d, t in zip(dummy_df['Date'], dummy_df['Time']):
    try:
        ts = dt.datetime.strptime(d + ' ' + t, '%m/%d/%Y %H:%M:%S')
        timestamp.append(time.mktime(ts.timetuple())) # inverse funtion of localtime
    except ValueError as e:
        timestamp.append('ValueError')

time_s = pd.Series(timestamp)
dummy_df['TimeStamp'] = time_s.values
dummy_df = dummy_df.drop(['Date', 'Time'], axis=1)

# %%
dummy_df.head()
# Out:
#      Latitude  Longitude  Type  Depth  Depth Error  Depth Seismic Stations  \
# 55     38.908    142.095     0   53.5          3.1                   412.0
# 89     40.697    143.032     0   32.1          3.1                   412.0
# 101    40.687    142.915     0   30.0          3.1                   412.0
# 111    36.083    139.968     0   50.0          3.1                   412.0
# 122    25.080    122.897     0  165.0          3.1                   412.0
#
#      Magnitude  Magnitude Type  Magnitude Error  Magnitude Seismic Stations  \
# 55         5.7               2             0.04                         7.0
# 89         6.4               2             0.04                         7.0
# 101        6.4               2             0.04                         7.0
# 111        5.7               2             0.04                         7.0
# 122        5.6               2             0.04                         7.0
#
#      Azimuthal Gap  Horizontal Distance  Horizontal Error  Root Mean Square  \
# 55           112.5                 3.36               5.9               1.0
# 89           112.5                 3.36               5.9               1.0
# 101          112.5                 3.36               5.9               1.0
# 111          112.5                 3.36               5.9               1.0
# 122          112.5                 3.36               5.9               1.0
#
#      Status  Place    TimeStamp
# 55        0    133 -153767150.0
# 89        0     81 -151332223.0
# 101       0     81 -150230542.0
# 111       0     42 -149558281.0
# 122       0    229 -148782010.0

# %% [markdown]
# ## Split into two

# %%
X = dummy_df[['Depth', 'Magnitude Error', 'Magnitude Type', 'Place', 'Depth Error', 
              'Azimuthal Gap', 'Horizontal Distance', 'Horizontal Error', 'Root Mean Square']]
y = dummy_df[['Latitude', 'Longitude', 'Magnitude']]

# %% [markdown]
# ## Train & Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)
# display(X_train)
# display(len(X_train))

# %% [markdown]
# ## Fitting the model -- __RandomForestRegressor__

# %%
reg = RandomForestRegressor()
reg.fit(X_train, y_train)
preds = reg.predict(X_test)
print(preds)
# Out:
# [[ 37.1959     141.262        5.82      ]
#  [ 39.442      143.1833       6.71      ]
#  [ 37.153      141.3507       5.99      ]
#  [ 34.90772    137.15577      6.03      ]
#  [ 38.92875    142.53005      5.9       ]
#  [ 24.4047     122.822        5.87      ]
#  [ 41.8598     139.3057       6.03      ]
#  [ 37.394      141.3134       5.79      ]
#  [ 37.2923     141.3847       5.93      ]
#  [ 38.6952     141.0724       5.69      ]
#  [ 38.7993     141.5966       5.83      ]
#  [ 32.3086     132.5775       5.93      ]
#  [ 39.9694     141.5383       5.83      ]
#  [ 32.91078    136.13056      5.75      ]
#  [ 33.0574     134.9513       5.62      ]
#  [ 39.7846     140.2036       5.72      ]
#  [ 39.327      143.1444       5.89      ]
#  [ 40.0813     143.223        5.75      ]
#  [ 33.0379     135.2231       5.82      ]
#  [ 40.1179     140.2          5.8       ]
#  [ 37.6875     141.3236       5.67      ]
#  [ 25.4046     124.8028       5.73      ]
#  [ 36.73809    141.82808      5.82      ]
#  [ 35.602      139.8231       5.85      ]
#  [ 41.1834     142.0671       5.99      ]
#  [ 39.9149     143.2697       5.59      ]
#  [ 24.3385     122.7204       5.73      ]
#  [ 41.7375     142.83165      5.925     ]
#  [ 31.3271     135.4878       5.83      ]
#  [ 37.35       141.5245       5.71      ]
#  [ 41.7409     143.8135       5.82      ]
#  [ 37.99933    142.57625      6.06      ]
#  [ 40.5805     142.1498       5.67      ]
#  [ 24.3677     122.7517       5.69      ]
#  [ 40.0632     142.576        6.02      ]
#  [ 39.7284     143.3896       5.8       ]
#  [ 37.9866     140.7418       5.5       ]
#  [ 36.1279     140.2671       5.97      ]
#  [ 36.56523    139.39591      6.15      ]
#  [ 36.82095    139.7709       5.92      ]
#  [ 32.72188    138.06612      5.9       ]
#  [ 38.3144     136.942        5.54      ]
#  [ 37.48947    140.39614      6.34      ]
#  [ 36.44243    138.93481      6.17      ]
#  [ 36.36041    140.60667      6.08      ]
#  [ 39.2376     142.5803       6.06      ]
#  [ 34.9891     135.72712      5.81      ]
#  [ 39.6797     142.8348       5.97      ]
#  [ 37.2258     141.7576       5.93      ]
#  [ 38.17118    141.86259      5.78      ]
#  [ 36.6718     141.5626       5.73      ]
#  [ 24.2307     122.6112       5.9       ]
#  [ 43.4496     139.8465       5.63      ]
#  [ 38.05218    141.02859      5.65      ]
#  [ 37.0006     139.9231       5.89      ]
#  [ 36.1308     141.4775       5.84      ]
#  [ 39.4057     142.3464       5.89      ]
#  [ 37.2618     138.8708       5.85      ]
#  [ 40.6554     143.4104       5.76      ]
#  [ 27.8603     128.9951       5.64      ]
#  [ 34.21594    137.67362      6.17      ]
#  [ 33.7617     137.5838       5.79      ]
#  [ 38.3436     141.5204       5.74      ]
#  [ 34.28804    138.88988      5.61      ]
#  [ 38.7467     142.1017       5.94      ]
#  [ 27.962      130.1696       7.04      ]
#  [ 40.5552     142.6926       5.99      ]
#  [ 37.0256     140.7277       5.74      ]
#  [ 37.4768     140.4569       5.86      ]
#  [ 36.59297    140.10947      6.01      ]
#  [ 36.84857667 142.01138667   5.84066667]
#  [ 40.1467     143.4513       5.65      ]
#  [ 29.1504     129.8761       6.15      ]
#  [ 38.3267     142.2073       5.78      ]
#  [ 33.47538    134.49735      5.86      ]
#  [ 34.84253    136.88911      5.89      ]
#  [ 39.1587     143.4525       6.07      ]
#  [ 32.8702     135.955        5.74      ]
#  [ 31.8439     133.8348       6.07      ]
#  [ 37.6409     141.9813       5.74      ]
#  [ 28.9803     129.5998       5.63      ]
#  [ 33.22398    134.71255      5.93      ]
#  [ 31.4653     133.4498       5.77      ]
#  [ 36.51938    139.33696      5.85      ]
#  [ 37.13821    139.668785     6.092     ]
#  [ 39.0115     141.8548       5.85      ]
#  [ 38.0432     141.7431       6.2       ]
#  [ 36.1109     135.4906       5.75      ]
#  [ 37.5966     138.82065      6.445     ]
#  [ 24.3927     122.7106       5.86      ]
#  [ 36.0786     142.0966       6.1       ]
#  [ 37.8853     140.709        5.74      ]
#  [ 37.1883     142.3133       5.74      ]
#  [ 30.1831     130.3285       5.83      ]
#  [ 34.9965     137.9238       5.84      ]
#  [ 36.36804    140.16259      5.94      ]
#  [ 33.5969     135.092        6.25      ]
#  [ 37.7945     138.6957       5.86      ]
#  [ 38.2752     141.9992       5.89      ]
#  [ 35.0259     136.9416       5.9       ]
#  [ 38.06968    141.80459      5.72      ]
#  [ 39.70835    140.89505      5.69      ]
#  [ 38.4856     142.2146       5.83      ]
#  [ 37.8517     142.337        6.15      ]
#  [ 34.8889     137.5924       6.02      ]
#  [ 29.0722     130.3313       5.94      ]
#  [ 33.69218    137.98074      5.62      ]
#  [ 36.2643     138.1441       5.76      ]
#  [ 37.2666     141.1569       6.16      ]
#  [ 37.5968     141.8954       5.8       ]
#  [ 38.0007     140.5569       5.78      ]
#  [ 37.23707    141.53104      5.76      ]
#  [ 35.38489    139.91622      5.68      ]
#  [ 36.0089     137.7042       5.77      ]
#  [ 35.8349     140.2829       5.72      ]
#  [ 37.554      139.4608       5.8       ]
#  [ 24.3989     122.5048       5.53      ]
#  [ 35.98395    140.33576      6.08      ]
#  [ 37.53641    140.572845     5.932     ]
#  [ 39.7538     143.4125       5.76      ]
#  [ 39.8865     143.451        5.78      ]
#  [ 35.44269    141.97232      6.07      ]
#  [ 29.4899     131.2744       5.96      ]
#  [ 41.6512     143.8767       7.52      ]
#  [ 33.1086     136.2528       6.13      ]]

# %%
accuracy = reg.score(X_test, y_test)
print(accuracy)
# Out:
# 0.7400954720686624

# %% [markdown]
# ## Fitting the model -- __GridSearchCV__

# %%
parameters = {'n_estimators' : [13, 18, 43, 77, 45, 450]}
gs = GridSearchCV(reg, parameters)

# %%
grid_fit = gs.fit(X_train, y_train)
best_fit = grid_fit.best_estimator_
gs_preds = best_fit.predict(X_test)
print(gs_preds)
# Out:
# [[ 37.41883488 141.43004651   5.7372093 ]
#  [ 39.43253488 143.16404651   6.73023256]
#  [ 37.23870698 141.24127442   6.06046512]
#  [ 35.43711163 138.30184651   5.95116279]
#  [ 35.94966163 140.26760426   5.89496124]
#  [ 24.44432558 122.83195349   5.89069767]
#  [ 37.25795349 137.98211628   5.98372093]
#  [ 37.28586047 140.01090698   5.81395349]
#  [ 37.72876744 141.29076744   6.02325581]
#  [ 38.27093256 141.6584814    5.83953488]
