# %%
import time
import datetime as dt
import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import linear_model
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

# %%
main_df = pd.read_csv('eq_database_place.csv')
dummy_eq = main_df.copy()

# %%
dummy_df = dummy_eq[dummy_eq['Place'].str.contains('US')]
# dummy_df = dummy_df.reindex(np.random.permutation(dummy_df.index))
dummy_df.head()
# Out:
#            Date      Time  Latitude  Longitude        Type  Depth  \
# 123  04/16/1965  23:22:21    64.572   -160.375  Earthquake   15.0
# 131  04/26/1965  20:29:07    54.157   -162.590  Earthquake   36.8
# 136  04/29/1965  15:28:45    47.288   -122.406  Earthquake   64.7
# 138  05/01/1965  21:27:54    60.350   -146.176  Earthquake   15.0
# 184  06/23/1965  11:09:17    56.543   -152.948  Earthquake   20.0
#
#      Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 123          NaN                     NaN        6.0             MW
# 131          NaN                     NaN        5.6             MW
# 136          NaN                     NaN        6.7             MW
# 138          NaN                     NaN        5.6             MW
# 184          NaN                     NaN        6.5             MW
#
#                 ...              Azimuthal Gap  Horizontal Distance  \
# 123             ...                        NaN                  NaN
# 131             ...                        NaN                  NaN
# 136             ...                        NaN                  NaN
# 138             ...                        NaN                  NaN
# 184             ...                        NaN                  NaN
#
#      Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 123               NaN               NaN  ISCGEM857809  ISCGEM          ISCGEM
# 131               NaN               NaN  ISCGEM858049  ISCGEM          ISCGEM
# 136               NaN               NaN  ISCGEM858143  ISCGEM          ISCGEM
# 138               NaN               NaN  ISCGEM856572  ISCGEM          ISCGEM
# 184               NaN               NaN  ISCGEM856357  ISCGEM          ISCGEM
#
#     Magnitude Source     Status                       Place
# 123           ISCGEM  Automatic                 Golovin, US
# 131           ISCGEM  Automatic  Aleutians East Borough, US
# 136           ISCGEM  Automatic                  Tacoma, US
# 138           ISCGEM  Automatic                 Cordova, US
# 184           ISCGEM  Automatic     Uhaiak (historical), US
#
# [5 rows x 22 columns]

# %% [markdown]
# ## NaN removing function

# %%
def nan_helper(y):
    """
    Helper to handle indices and logical indices of NaNs.
    Input:
        - y, 1d numpy array with possible NaNs
    Output:
        - nans, logical indices of NaNs
        - index, a function, with signature indices= index(logical_indices),
          to convert logical indices of NaNs to 'equivalent' indices
    Example:
        >>> # linear interpolation of NaNs
        >>> nans, x= nan_helper(y)
        >>> y[nans]= np.interp(x(nans), x(~nans), y[~nans])
    """
    
    return np.isnan(y), lambda z: z.nonzero()[0]

# %% [markdown]
# ## String label encoding

# %%
def label_integer_encoder(my_df, series_name):
    """
    This function is encoding values of a series
    Parameter
    ---------
    * `my_df`: Pandas dataframe
    * `series_name`: Pandas series name to encode
    Returns : a encoded array
    """
    arr_name = np.array(list(my_df[str(series_name)]))
    label_arr_encoder = LabelEncoder()
    integer_arr_encoded = label_arr_encoder.fit_transform(arr_name)
    
    return integer_arr_encoded

# %% [markdown]
# ## Interpolation function

# %%
def get_interpolation(my_df, nan_series):
    arr_series = np.array(my_df[str(nan_series)])
    nans, x = nan_helper(arr_series)
    arr_series[nans] = np.interp(x(nans), x(~nans), arr_series[~nans])
    return arr_series.round(2)

# %% [markdown]
# ## Removing NaN values from the series

# %%
dummy_df['Depth Error'] = get_interpolation(dummy_df, 'Depth Error')
dummy_df['Depth Seismic Stations'] = get_interpolation(dummy_df, 'Depth Seismic Stations')
dummy_df['Magnitude Error'] = get_interpolation(dummy_df, 'Magnitude Error')
dummy_df['Magnitude Seismic Stations'] = get_interpolation(dummy_df, 'Magnitude Seismic Stations')
dummy_df['Azimuthal Gap'] = get_interpolation(dummy_df, 'Azimuthal Gap')
dummy_df['Horizontal Distance'] = get_interpolation(dummy_df, 'Horizontal Distance')
dummy_df['Horizontal Error'] = get_interpolation(dummy_df, 'Horizontal Error')
dummy_df['Root Mean Square'] = get_interpolation(dummy_df, 'Root Mean Square')

# %% [markdown]
# ## Actual encoding of strings

# %%
dummy_df['Type'] = label_integer_encoder(dummy_df, 'Type')
dummy_df['Magnitude Type'] = label_integer_encoder(dummy_df, 'Magnitude Type')
dummy_df['Place'] = label_integer_encoder(dummy_df, 'Place')
dummy_df['Status'] = label_integer_encoder(dummy_df, 'Status')

# %% [markdown]
# ## Dropping unwanted

# %%
dummy_df = dummy_df.drop(['ID', 'Source', 'Location Source', 'Magnitude Source'], axis=1)

# %% [markdown]
# ## Time object numerical values

# %%
timestamp = []
for d, t in zip(dummy_df['Date'], dummy_df['Time']):
    try:
        ts = dt.datetime.strptime(d + ' ' + t, '%m/%d/%Y %H:%M:%S')
        timestamp.append(time.mktime(ts.timetuple())) # inverse funtion of localtime
    except ValueError as e:
        timestamp.append('ValueError')

time_s = pd.Series(timestamp)
dummy_df['TimeStamp'] = time_s.values
dummy_df = dummy_df.drop(['Date', 'Time'], axis=1)

# %%
dummy_df.head()
# Out:
#      Latitude  Longitude  Type  Depth  Depth Error  Depth Seismic Stations  \
# 123    64.572   -160.375     0   15.0        31.61                    16.0
# 131    54.157   -162.590     0   36.8        31.61                    16.0
# 136    47.288   -122.406     0   64.7        31.61                    16.0
# 138    60.350   -146.176     0   15.0        31.61                    16.0
# 184    56.543   -152.948     0   20.0        31.61                    16.0
#
#      Magnitude  Magnitude Type  Magnitude Error  Magnitude Seismic Stations  \
# 123        6.0               5             0.24                        10.0
# 131        5.6               5             0.24                        10.0
# 136        6.7               5             0.24                        10.0
# 138        5.6               5             0.24                        10.0
# 184        6.5               5             0.24                        10.0
#
#      Azimuthal Gap  Horizontal Distance  Horizontal Error  Root Mean Square  \
# 123          261.0                 1.48              99.0              0.86
# 131          261.0                 1.48              99.0              0.86
# 136          261.0                 1.48              99.0              0.86
# 138          261.0                 1.48              99.0              0.86
# 184          261.0                 1.48              99.0              0.86
#
#      Status  Place    TimeStamp
# 123       0     55 -148630059.0
# 131       0      4 -147776453.0
# 136       0    123 -147535275.0
# 138       0     33 -147340926.0
# 184       0    129 -142798843.0

# %% [markdown]
# ## Split into two

# %%
X = dummy_df[['Latitude', 'Longitude', 'Magnitude Error', 'Magnitude Type', 'Depth Error', 
              'Azimuthal Gap', 'Horizontal Distance', 'Horizontal Error', 'Root Mean Square']]
y = dummy_df[['Magnitude', 'Depth']]

# %% [markdown]
# ## Train & Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# ## Fitting the model -- __RandomForestRegressor__

# %%
reg = RandomForestRegressor()
reg.fit(X_train, y_train)
preds = reg.predict(X_test)
print(preds)
# Out:
# [[  6.082   11.0038]
#  [  6.11    32.26  ]
#  [  6.21    43.67  ]
#  [  5.854    8.523 ]
#  [  5.66    33.    ]
#  [  5.735    7.2687]
#  [  5.84    23.7   ]
#  [  5.8    116.24  ]
#  [  5.99    37.48  ]
#  [  5.61    78.07  ]
#  [  6.16    14.09  ]
#  [  5.886    9.5164]
#  [  5.58    34.    ]
#  [  6.03    38.06  ]
#  [  5.8     45.92  ]
#  [  6.34    29.77  ]
#  [  5.65    39.31  ]
#  [  5.87    32.97  ]
#  [  5.835    8.4034]
#  [  5.84    43.57  ]
#  [  6.087    8.202 ]
#  [  5.58    11.4781]
#  [  6.069   10.9253]
#  [  5.86    27.2   ]
#  [  5.79    36.65  ]
#  [  5.91   112.4   ]
#  [  5.905    6.4128]
#  [  5.98    41.04  ]
#  [  5.74    44.08  ]
#  [  5.76    56.99  ]
#  [  5.8     32.03  ]
#  [  5.95    68.67  ]
#  [  5.68    33.    ]
#  [  5.66    30.7   ]
#  [  5.6     35.    ]
#  [  5.9     14.48  ]
#  [  5.86    34.07  ]
#  [  5.94    13.7   ]
#  [  5.9     63.62  ]
#  [  5.82    33.95  ]
#  [  5.82     8.3022]
#  [  5.86    42.19  ]
#  [  5.71    18.803 ]
#  [  5.81    29.17  ]
#  [  5.7     47.7   ]
#  [  5.82    29.85  ]
#  [  6.14    30.69  ]
#  [  5.599    3.62  ]
#  [  6.1      7.3125]
#  [  6.27    34.354 ]
#  [  6.83     2.9746]
#  [  5.83   121.49  ]
#  [  5.94    26.886 ]
#  [  5.96    35.3896]
#  [  5.77    29.6   ]
#  [  5.81    24.034 ]
#  [  5.78   128.96  ]
#  [  5.99    28.93  ]
#  [  5.79    35.35  ]
#  [  5.83    32.8   ]
#  [  5.67    88.14  ]
#  [  6.01    42.5   ]
#  [  5.78    12.86  ]
#  [  5.82    49.39  ]
#  [  5.817    5.6042]
#  [  5.86    30.74  ]
#  [  6.254    8.4393]
#  [  6.02    21.6   ]
#  [  5.85    16.309 ]
#  [  5.84     7.4594]
#  [  5.66    31.54  ]
#  [  5.86    23.422 ]
#  [  5.821    9.8214]
#  [  5.82    32.85  ]
#  [  6.25    43.07  ]
#  [  6.13    32.33  ]
#  [  6.111    6.1855]
#  [  5.92    26.89  ]
#  [  6.36    28.62  ]
#  [  6.51    29.81  ]
#  [  5.93    32.13  ]
#  [  6.22    11.6518]
#  [  5.6      8.3   ]
#  [  5.818    9.5135]
#  [  5.82    23.149 ]
#  [  5.83    19.95  ]
#  [  5.8     80.13  ]
#  [  6.236    9.0865]
#  [  5.72    68.59  ]
#  [  5.8     31.15  ]
#  [  6.06    30.3   ]
#  [  5.727   10.6002]
#  [  5.785    2.1706]
#  [  5.85     9.02  ]
#  [  5.58    33.    ]
#  [  5.99    37.67  ]
#  [  5.81    98.    ]
#  [  5.72    32.77  ]
#  [  5.94   124.47  ]
#  [  6.26    19.7   ]
#  [  5.81    30.9   ]
#  [  5.78    11.03  ]
#  [  6.32    37.909 ]
#  [  6.11    30.96  ]
#  [  6.23    13.35  ]
#  [  5.937    5.0606]
#  [  6.33     9.8   ]
#  [  6.02    21.49  ]
#  [  5.66    38.84  ]
#  [  5.73    28.9   ]
#  [  5.84    54.29  ]
#  [  6.05    26.4   ]
#  [  5.832   15.8828]
#  [  6.029   10.1058]
#  [  5.83    37.54  ]
#  [  5.749    5.5893]
#  [  5.68    39.44  ]
#  [  6.15    58.88  ]
#  [  5.86    63.55  ]
#  [  5.87   132.89  ]
#  [  5.9     33.94  ]
#  [  5.81    46.679 ]
#  [  6.47    25.97  ]
#  [  5.976    8.7547]
#  [  5.96    27.589 ]
#  [  6.15    28.16  ]
#  [  6.02    47.01  ]
#  [  5.91    23.5   ]
#  [  5.8     93.31  ]
#  [  5.89     4.1667]
#  [  5.86    23.6   ]
#  [  5.95    31.4   ]
#  [  6.12     9.15  ]
#  [  5.927   10.2107]
#  [  5.81    51.13  ]]

# %%
accuracy = reg.score(X_test, y_test)
print(accuracy)
# Out:
# 0.6481051614857934

# %% [markdown]
# ## Fitting the model -- __GridSearchCV__

# %%
parameters = {'n_estimators' : [13, 18, 43, 77, 45, 450]}
gs = GridSearchCV(reg, parameters)

# %%
grid_fit = gs.fit(X_train, y_train)
best_fit = grid_fit.best_estimator_
gs_preds = best_fit.predict(X_test)
print(gs_preds)
# Out:
# [[  5.97022222  10.09718889]
#  [  6.08422222  28.33151111]
#  [  5.948       39.12222222]
#  [  5.9966       7.63327778]
#  [  5.66266667  30.42911111]
#  [  5.79095556   7.08177556]
#  [  5.93377778  29.60466667]
#  [  5.81888889 112.09111111]
#  [  6.00177778  35.06591111]
#  [  5.668       61.04755556]
#  [  6.10255556  15.09117111]
#  [  5.93397778   8.97686889]
#  [  5.72711111  35.08109778]
#  [  5.81177778  36.64755556]
#  [  5.76755556  47.44148889]
#  [  6.26577778  32.87893333]
#  [  5.89644444  77.80948889]
#  [  5.88044444  29.38484444]
#  [  5.96682222  10.90902222]
#  [  5.98422222  40.36586667]
#  [  6.12566667   8.96824444]
#  [  5.70024444   8.82429778]
#  [  5.9408       9.63674667]
#  [  5.93777778  35.93562222]
#  [  5.86066667  31.53375556]
#  [  5.94355556 118.67777778]
#  [  5.89117778   5.90024667]
#  [  6.016       37.59646222]
#  [  5.89088889  39.45631111]
#  [  5.68644444  55.14822222]
#  [  5.77511111  32.39355556]
#  [  5.82222222  53.63177778]
#  [  5.80888889  37.01671111]
#  [  5.76622222  39.28635556]
#  [  5.63822222  35.99266667]
#  [  5.83555556  16.35825556]
#  [  5.88244444  34.27551111]
#  [  5.91333333  12.05955556]
#  [  5.94288889  48.35408889]
#  [  5.75488889  35.5268    ]
#  [  5.97326667   8.86778667]
#  [  5.83377778  32.34515556]
#  [  5.80866667  21.41802222]
#  [  5.84977778  33.58933333]
#  [  5.72155556  40.3732    ]
#  [  5.932       30.62017778]
#  [  6.04177778  30.23622222]
#  [  5.73142222   2.84998889]
#  [  5.90875556   6.74424889]
#  [  6.11644444  33.26488889]
#  [  6.54077778   9.24569778]
#  [  5.80222222 120.30844444]
#  [  5.72577778  30.34475556]
#  [  6.12746667  35.93877778]
#  [  5.81177778  31.81435556]
#  [  5.824       30.24124444]
#  [  5.74711111 124.97666667]
#  [  5.90022222  28.89328889]
#  [  5.75911111  31.47911111]
#  [  5.774       33.67222222]
#  [  5.71044444  88.926     ]
#  [  5.838       58.74735556]
#  [  5.72235556  14.37645556]
#  [  5.89955556  53.25711111]
#  [  5.82826667   6.17123778]
#  [  5.89488889  35.05813333]
#  [  5.97995556   7.90363333]
#  [  5.95444444  20.6792    ]
#  [  5.89155556  28.76593333]
#  [  5.93604444   7.28619111]
#  [  5.67977778  34.41888889]
#  [  6.052       21.56971111]
#  [  5.81031111   9.09674667]
#  [  5.82888889  32.95688889]
#  [  5.96177778  35.90111111]
#  [  6.28288889  33.47355556]
#  [  6.10448889   6.46195778]
#  [  6.03088889  28.21822222]
#  [  6.11        26.76919333]
#  [  6.08311111  26.257     ]
#  [  5.79844444  33.14511111]
#  [  6.00742222   9.57609333]
#  [  5.69444444  10.59035778]
#  [  5.8588       9.65112222]
#  [  5.862       32.19815556]
#  [  5.82244444  14.24686667]
#  [  5.72        61.38889556]
#  [  5.98957778   8.04706222]
#  [  5.85755556  70.9304    ]
#  [  5.85066667  26.09844444]
#  [  5.99933333  32.14742222]
#  [  5.83553333  11.67247333]
#  [  5.76466667   2.42631556]
#  [  5.85086667  10.59716889]
#  [  5.61311111  32.41311111]
#  [  5.87777778  37.601     ]
#  [  5.67888889  83.60688889]
#  [  5.77266667  35.35533333]
#  [  5.94666667 130.016     ]
#  [  6.04222222  24.07868889]
#  [  5.78822222  36.28875556]
#  [  5.83973333  15.09602   ]
#  [  5.95986667  19.13760222]
#  [  5.85733333  32.11795556]
#  [  6.29968889  19.88363333]
#  [  5.8168       4.16693778]
#  [  6.47         9.39422   ]
#  [  6.00888889  31.36044444]
#  [  5.75        40.02582222]
#  [  5.66088889  28.19168889]
#  [  5.78755556  72.84466667]
#  [  6.01533333  28.08013333]
#  [  5.93337778  19.56868667]
#  [  5.96857778   8.71745111]
#  [  5.88444444  36.40317778]
#  [  5.75406667   5.07629111]
#  [  5.78377778  43.73402222]
#  [  5.83377778 105.26      ]
#  [  5.96844444  47.98013333]
#  [  5.93222222 136.21955556]
#  [  5.86555556  21.72586444]
#  [  5.96666667  85.2842    ]
#  [  6.08177778  31.34591111]
#  [  5.89942222   8.34330667]
#  [  5.91488889  25.78802222]
#  [  5.94711111  40.57008889]
#  [  5.874       36.13108889]
#  [  5.82648889  29.42046222]
#  [  5.84288889  97.69288889]
#  [  5.91762222   4.88310222]
#  [  5.73422222  23.94737778]
#  [  5.96155556  30.74364444]
#  [  5.84211111  11.90193556]
#  [  5.90015556   8.69860889]
#  [  5.78688889  46.96066667]]

# %%
gs_accuracy = best_fit.score(X_test, y_test)
print(gs_accuracy)
# Out:
# 0.79318404374048
