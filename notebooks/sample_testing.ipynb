# %%
import time
import datetime as dt
import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import linear_model
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

# %%
main_df = pd.read_csv('eq_database_place.csv')
dummy_eq = main_df.copy()

# %%
dummy_df = dummy_eq[dummy_eq['Place'].str.contains('US')]
# dummy_df = dummy_df.reindex(np.random.permutation(dummy_df.index))
dummy_df.head()
# Out:
#            Date      Time  Latitude  Longitude        Type  Depth  \
# 123  04/16/1965  23:22:21    64.572   -160.375  Earthquake   15.0
# 131  04/26/1965  20:29:07    54.157   -162.590  Earthquake   36.8
# 136  04/29/1965  15:28:45    47.288   -122.406  Earthquake   64.7
# 138  05/01/1965  21:27:54    60.350   -146.176  Earthquake   15.0
# 184  06/23/1965  11:09:17    56.543   -152.948  Earthquake   20.0
#
#      Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 123          NaN                     NaN        6.0             MW
# 131          NaN                     NaN        5.6             MW
# 136          NaN                     NaN        6.7             MW
# 138          NaN                     NaN        5.6             MW
# 184          NaN                     NaN        6.5             MW
#
#                 ...              Azimuthal Gap  Horizontal Distance  \
# 123             ...                        NaN                  NaN
# 131             ...                        NaN                  NaN
# 136             ...                        NaN                  NaN
# 138             ...                        NaN                  NaN
# 184             ...                        NaN                  NaN
#
#      Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 123               NaN               NaN  ISCGEM857809  ISCGEM          ISCGEM
# 131               NaN               NaN  ISCGEM858049  ISCGEM          ISCGEM
# 136               NaN               NaN  ISCGEM858143  ISCGEM          ISCGEM
# 138               NaN               NaN  ISCGEM856572  ISCGEM          ISCGEM
# 184               NaN               NaN  ISCGEM856357  ISCGEM          ISCGEM
#
#     Magnitude Source     Status                       Place
# 123           ISCGEM  Automatic                 Golovin, US
# 131           ISCGEM  Automatic  Aleutians East Borough, US
# 136           ISCGEM  Automatic                  Tacoma, US
# 138           ISCGEM  Automatic                 Cordova, US
# 184           ISCGEM  Automatic     Uhaiak (historical), US
#
# [5 rows x 22 columns]

# %% [markdown]
# ## NaN removing function

# %%
def nan_helper(y):
    """
    Helper to handle indices and logical indices of NaNs.
    Input:
        - y, 1d numpy array with possible NaNs
    Output:
        - nans, logical indices of NaNs
        - index, a function, with signature indices= index(logical_indices),
          to convert logical indices of NaNs to 'equivalent' indices
    Example:
        >>> # linear interpolation of NaNs
        >>> nans, x= nan_helper(y)
        >>> y[nans]= np.interp(x(nans), x(~nans), y[~nans])
    """
    
    return np.isnan(y), lambda z: z.nonzero()[0]

# %% [markdown]
# ## String label encoding

# %%
def label_integer_encoder(my_df, series_name):
    """
    This function is encoding values of a series
    Parameter
    ---------
    * `my_df`: Pandas dataframe
    * `series_name`: Pandas series name to encode
    Returns : a encoded array
    """
    arr_name = np.array(list(my_df[str(series_name)]))
    label_arr_encoder = LabelEncoder()
    integer_arr_encoded = label_arr_encoder.fit_transform(arr_name)
    
    return integer_arr_encoded

# %% [markdown]
# ## Interpolation function

# %%
def get_interpolation(my_df, nan_series):
    arr_series = np.array(my_df[str(nan_series)])
    nans, x = nan_helper(arr_series)
    arr_series[nans] = np.interp(x(nans), x(~nans), arr_series[~nans])
    return arr_series.round(2)

# %% [markdown]
# ## Removing NaN values from the series

# %%
dummy_df['Depth Error'] = get_interpolation(dummy_df, 'Depth Error')
dummy_df['Depth Seismic Stations'] = get_interpolation(dummy_df, 'Depth Seismic Stations')
dummy_df['Magnitude Error'] = get_interpolation(dummy_df, 'Magnitude Error')
dummy_df['Magnitude Seismic Stations'] = get_interpolation(dummy_df, 'Magnitude Seismic Stations')
dummy_df['Azimuthal Gap'] = get_interpolation(dummy_df, 'Azimuthal Gap')
dummy_df['Horizontal Distance'] = get_interpolation(dummy_df, 'Horizontal Distance')
dummy_df['Horizontal Error'] = get_interpolation(dummy_df, 'Horizontal Error')
dummy_df['Root Mean Square'] = get_interpolation(dummy_df, 'Root Mean Square')

# %% [markdown]
# ## Actual encoding of strings

# %%
dummy_df['Type'] = label_integer_encoder(dummy_df, 'Type')
dummy_df['Magnitude Type'] = label_integer_encoder(dummy_df, 'Magnitude Type')
dummy_df['Place'] = label_integer_encoder(dummy_df, 'Place')
dummy_df['Status'] = label_integer_encoder(dummy_df, 'Status')

# %% [markdown]
# ## Dropping unwanted

# %%
dummy_df = dummy_df.drop(['ID', 'Source', 'Location Source', 'Magnitude Source'], axis=1)

# %% [markdown]
# ## Time object numerical values

# %%
timestamp = []
for d, t in zip(dummy_df['Date'], dummy_df['Time']):
    try:
        ts = dt.datetime.strptime(d + ' ' + t, '%m/%d/%Y %H:%M:%S')
        timestamp.append(time.mktime(ts.timetuple())) # inverse funtion of localtime
    except ValueError as e:
        timestamp.append('ValueError')

time_s = pd.Series(timestamp)
dummy_df['TimeStamp'] = time_s.values
dummy_df = dummy_df.drop(['Date', 'Time'], axis=1)

# %%
dummy_df.head()
# Out:
#      Latitude  Longitude  Type  Depth  Depth Error  Depth Seismic Stations  \
# 123    64.572   -160.375     0   15.0        31.61                    16.0
# 131    54.157   -162.590     0   36.8        31.61                    16.0
# 136    47.288   -122.406     0   64.7        31.61                    16.0
# 138    60.350   -146.176     0   15.0        31.61                    16.0
# 184    56.543   -152.948     0   20.0        31.61                    16.0
#
#      Magnitude  Magnitude Type  Magnitude Error  Magnitude Seismic Stations  \
# 123        6.0               5             0.24                        10.0
# 131        5.6               5             0.24                        10.0
# 136        6.7               5             0.24                        10.0
# 138        5.6               5             0.24                        10.0
# 184        6.5               5             0.24                        10.0
#
#      Azimuthal Gap  Horizontal Distance  Horizontal Error  Root Mean Square  \
# 123          261.0                 1.48              99.0              0.86
# 131          261.0                 1.48              99.0              0.86
# 136          261.0                 1.48              99.0              0.86
# 138          261.0                 1.48              99.0              0.86
# 184          261.0                 1.48              99.0              0.86
#
#      Status  Place    TimeStamp
# 123       0     55 -148630059.0
# 131       0      4 -147776453.0
# 136       0    123 -147535275.0
# 138       0     33 -147340926.0
# 184       0    129 -142798843.0

# %% [markdown]
# ## Split into two

# %%
X = dummy_df[['Latitude', 'Longitude', 'Magnitude Error', 'Magnitude Type', 'Depth Error', 
              'Azimuthal Gap', 'Horizontal Distance', 'Horizontal Error', 'Root Mean Square']]
y = dummy_df[['Magnitude', 'Depth']]

# %% [markdown]
# ## Train & Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# ## Fitting the model -- __RandomForestRegressor__

# %%
reg = RandomForestRegressor()
reg.fit(X_train, y_train)
preds = reg.predict(X_test)
print(preds)
# Out:
# [[  5.912   10.3815]
#  [  6.11    21.72  ]
#  [  5.88    36.34  ]
#  [  5.987    9.836 ]
#  [  5.69    23.49  ]
#  [  5.843    8.1935]
#  [  5.84    32.192 ]
#  [  5.89   112.95  ]
#  [  5.91    33.85  ]
#  [  5.71    71.21  ]
#  [  6.      11.39  ]
#  [  6.061    9.7728]
#  [  5.6     39.01  ]
#  [  5.97    36.68  ]
#  [  5.71    42.52  ]
#  [  6.02    32.36  ]
#  [  5.87    67.43  ]
#  [  5.81    29.24  ]
#  [  5.872    7.8313]
#  [  5.97    39.471 ]
#  [  6.201   10.098 ]
#  [  5.688    8.1358]
#  [  5.866    6.7558]
#  [  5.95    40.54  ]
#  [  5.88    22.999 ]
#  [  5.91   124.98  ]
#  [  5.734    6.723 ]
#  [  6.      37.16  ]
#  [  5.95    50.04  ]
#  [  5.66    56.1   ]
#  [  5.8     31.1   ]
#  [  5.87    54.65  ]
#  [  5.77    29.3   ]
#  [  5.66    31.2   ]
#  [  5.67    36.2   ]
#  [  5.73    12.12  ]
#  [  5.9     31.07  ]
#  [  5.87    10.2   ]
#  [  5.64    50.    ]
#  [  5.74    35.46  ]
#  [  5.848    9.6443]
#  [  5.78    23.39  ]
#  [  5.85    17.42  ]
#  [  5.97    28.1   ]
#  [  5.73    42.73  ]
#  [  5.96    39.13  ]
#  [  6.05    30.39  ]
#  [  5.684    3.14  ]
#  [  6.03     8.1749]
#  [  6.12    33.78  ]
#  [  6.546   12.1436]
#  [  6.04   127.64  ]
#  [  5.72    31.686 ]
#  [  6.23    39.6042]
#  [  5.81    31.6   ]
#  [  5.98    43.27  ]
#  [  5.77   130.98  ]
#  [  5.75    28.36  ]
#  [  5.77    35.53  ]
#  [  5.74    32.5   ]
#  [  5.85    93.5   ]
#  [  5.92    49.93  ]
#  [  5.63    11.15  ]
#  [  6.06    60.35  ]
#  [  5.985    5.8306]
#  [  5.76    31.689 ]
#  [  5.974    8.4929]
#  [  6.06    20.973 ]
#  [  5.68    38.581 ]
#  [  5.88     6.8411]
#  [  5.75    33.63  ]
#  [  6.03    21.72  ]
#  [  5.818    9.3006]
#  [  6.01    32.94  ]
#  [  6.12    36.4   ]
#  [  6.11    34.57  ]
#  [  6.21     8.8661]
#  [  5.87    29.4   ]
#  [  6.1     24.65  ]
#  [  6.28    14.81  ]
#  [  5.81    33.    ]
#  [  5.922    8.3076]
#  [  5.7     10.9692]
#  [  5.846    6.4038]
#  [  5.84    36.03  ]
#  [  6.03    14.54  ]
#  [  5.76    69.12  ]
#  [  6.064    7.7998]
#  [  5.86    62.31  ]
#  [  5.99    25.53  ]
#  [  6.07    29.    ]
#  [  5.798   11.3988]
#  [  5.801    1.64  ]
#  [  5.93    10.1803]
#  [  5.6     33.    ]
#  [  6.17    24.85  ]
#  [  5.63    84.27  ]
#  [  5.71    39.66  ]
#  [  6.13   133.26  ]
#  [  6.29    16.86  ]
#  [  5.71    31.1   ]
#  [  5.61    17.89  ]
#  [  6.22    34.1394]
#  [  6.06    32.43  ]
#  [  6.41    21.28  ]
#  [  5.694    3.1326]
#  [  6.51     6.56  ]
#  [  6.02    34.57  ]
#  [  5.76    39.59  ]
#  [  5.65    31.2   ]
#  [  5.79    76.79  ]
#  [  5.94    41.699 ]
#  [  6.07    22.1478]
#  [  5.909    6.7589]
#  [  5.64    29.28  ]
#  [  5.704    4.16  ]
#  [  5.71    36.01  ]
#  [  5.69   116.7   ]
#  [  5.82    47.5   ]
#  [  5.86   131.76  ]
#  [  5.82     9.72  ]
#  [  5.82    75.5   ]
#  [  5.92    29.3   ]
#  [  6.083    8.625 ]
#  [  5.83    31.32  ]
#  [  6.05    24.46  ]
#  [  5.85    38.93  ]
#  [  5.91    21.83  ]
#  [  5.83    95.51  ]
#  [  5.99     3.1055]
#  [  5.7     24.    ]
#  [  6.04    27.87  ]
#  [  5.83     9.38  ]
#  [  5.669    8.3332]
#  [  5.78    47.06  ]]

# %%
accuracy = reg.score(X_test, y_test)
print(accuracy)
# Out:
# 0.7774661713138058

# %% [markdown]
# ## Fitting the model -- __GridSearchCV__

# %%
parameters = {'n_estimators' : [13, 18, 43, 77, 45, 450]}
gs = GridSearchCV(reg, parameters)

# %%
grid_fit = gs.fit(X_train, y_train)
best_fit = grid_fit.best_estimator_
gs_preds = best_fit.predict(X_test)
print(gs_preds)
# Out:
# [[  5.97571429  10.20233766]
#  [  6.14025974  25.32597403]
#  [  5.92207792  38.13766234]
#  [  5.99493506   7.57977922]
#  [  5.71298701  30.04155844]
#  [  5.71064935   6.91209091]
#  [  5.86493506  30.15402597]
#  [  5.85844156 107.9961039 ]
#  [  5.92077922  34.34415584]
#  [  5.64675325  65.76233766]
#  [  6.15532468  13.04709091]
#  [  5.9238961    8.84696104]
#  [  5.67792208  32.24545455]
#  [  5.81818182  37.71558442]
#  [  5.77532468  45.91636364]
#  [  6.22857143  32.84675325]
#  [  5.85194805  73.46077922]
#  [  5.94545455  30.64779221]
#  [  6.03792208  11.74112987]
#  [  5.98051948  37.18662338]
#  [  6.13207792   8.78933766]
#  [  5.64649351   8.6177013 ]
#  [  5.89922078   9.52542857]
#  [  5.95324675  35.88441558]
#  [  5.86493506  31.82116883]
#  [  5.88961039 120.36233766]
#  [  5.91142857   5.16554545]
#  [  6.02207792  37.25506494]
#  [  5.8987013   39.37792208]
#  [  5.72337662  54.48571429]
#  [  5.81428571  32.16103896]
#  [  5.78701299  48.87532468]
#  [  5.82077922  35.18467532]
#  [  5.75584416  35.38077922]
#  [  5.62857143  35.3961039 ]
#  [  5.91038961  18.04935065]
#  [  5.83376623  36.91298701]
#  [  5.93376623  14.36887013]
#  [  5.92077922  43.74844156]
#  [  5.81558442  34.44285714]
#  [  5.93714286   7.59357143]
#  [  5.83376623  31.35766234]
#  [  5.83506494  20.87831169]
#  [  5.84935065  32.52207792]
#  [  5.76363636  41.51025974]
#  [  5.96233766  31.09168831]
#  [  6.08571429  28.27792208]
#  [  5.75584416   2.55179221]
#  [  5.92038961   6.83645455]
#  [  6.04805195  32.18441558]
#  [  6.52311688   8.73090909]
#  [  5.78701299 119.42077922]
#  [  5.69220779  30.85064935]
#  [  6.11818182  36.49564935]
#  [  5.83116883  32.38441558]
#  [  5.90649351  30.81168831]
#  [  5.81558442 125.97012987]
#  [  5.87402597  30.34922078]
#  [  5.73246753  29.33506494]
#  [  5.77142857  33.88831169]
#  [  5.69350649  86.61948052]
#  [  5.83116883  61.56753247]
#  [  5.72415584  13.96397403]
#  [  5.9025974   50.91948052]
#  [  5.84441558   6.05350649]
#  [  5.90519481  33.12207792]
#  [  6.01974026   8.45172727]
#  [  5.95454545  21.48220779]
#  [  5.88051948  32.15948052]
#  [  5.9387013    7.59666234]
#  [  5.71428571  30.44935065]
#  [  6.07792208  21.44571429]
#  [  5.82480519   9.16392208]
#  [  5.80649351  36.10779221]
#  [  5.91168831  34.11402597]
#  [  6.2987013   31.92233766]
#  [  6.03272727   6.5584026 ]
#  [  6.06493506  27.58701299]
#  [  6.13246753  26.05194805]
#  [  6.08441558  23.74402597]
#  [  5.78181818  32.93714286]
#  [  5.8774026    9.29094805]
#  [  5.63636364  10.98820779]
#  [  5.93246753   9.35561039]
#  [  5.84805195  32.59857143]
#  [  5.78311688  13.96064935]
#  [  5.81428571  63.14155844]
#  [  5.99168831   8.80007792]
#  [  5.84805195  64.44558442]
#  [  5.87272727  25.52727273]
#  [  5.9987013   31.82857143]
#  [  5.76220779  10.87994805]
#  [  5.7425974    2.67662338]
#  [  5.86272727   8.38415584]
#  [  5.5974026   32.75064935]
#  [  5.86233766  35.30909091]
#  [  5.71688312  89.00779221]
#  [  5.80779221  33.86623377]
#  [  6.04545455 130.16753247]
#  [  6.04805195  23.25051948]
#  [  5.7961039   35.00805195]
#  [  5.83337662  13.85466234]
#  [  5.97272727  19.26881818]
#  [  5.87402597  32.56883117]
#  [  6.26753247  23.16116883]
#  [  5.82090909   4.00815584]
#  [  6.3974026    7.81415584]
#  [  6.01818182  30.91688312]
#  [  5.7961039   43.64415584]
#  [  5.68311688  27.26311688]
#  [  5.76883117  72.59090909]
#  [  5.97272727  29.02493506]
#  [  5.84025974  19.82537662]
#  [  6.02974026   9.81598701]
#  [  5.89220779  35.80753247]
#  [  5.74194805   4.70792208]
#  [  5.78571429  44.57272727]
#  [  5.90649351 105.77168831]
#  [  5.95584416  43.40402597]
#  [  5.92597403 132.62857143]
#  [  5.87402597  16.96766234]
#  [  5.86883117  82.19103896]
#  [  6.05064935  31.86051948]
#  [  5.89584416   8.53742857]
#  [  5.91298701  26.53922078]
#  [  5.98701299  44.94285714]
#  [  5.85584416  36.83246753]
#  [  5.75454545  32.14025974]
#  [  5.87272727  97.37792208]
#  [  5.96051948   5.66287013]
#  [  5.74545455  24.37662338]
#  [  5.99220779  29.17584416]
#  [  5.98181818  10.09094805]
#  [  5.8425974    8.31448052]
#  [  5.77532468  42.49220779]]

# %%
gs_accuracy = best_fit.score(X_test, y_test)
print(gs_accuracy)
# Out:
# 0.7878061462506243
